# %% [markdown]
# ### [3650 边反转的最小路径成本](https://leetcode.cn/problems/minimum-cost-path-with-edge-reversals/description/?envType=daily-question&envId=2026-01-26)
# <font color=#FFCC33>中等</font>

# %%
from typing import List


class Solution:
    def minCost(self, n: int, edges: List[List[int]]) -> int:
