# %% [markdown]
# ### [3640 三段式数组 II](https://leetcode.cn/problems/trionic-array-ii/description/?envType=daily-question&envId=2026-01-26)
# <font color=#FF3366>困难</font>

# %%
from typing import List


class Solution:
    def maxSumTrionic(self, nums: List[int]) -> int:
