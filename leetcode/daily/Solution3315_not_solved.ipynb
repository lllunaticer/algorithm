# %% [markdown]
# ### [3315 构造最小位运算数组](https://leetcode.cn/problems/construct-the-minimum-bitwise-array-ii/?envType=daily-question&envId=2026-01-22)
# <font color=#FFCC33>中等</font>

# %%
from typing import List


class Solution:
    def minBitwiseArray(self, nums: List[int]) -> List[int]:
