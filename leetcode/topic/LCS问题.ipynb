# %% [markdown]
# ### LCS专题

# %% [markdown]
# [1143. 最长公共子序列](https://leetcode.cn/problems/longest-common-subsequence/)  + [solution](../daily/Solution1143.ipynb)
# [583. 两个字符串的删除操作](https://leetcode.cn/problems/delete-operation-for-two-strings/)
# [712. 两个字符串的最小 ASCII 删除和](https://leetcode.cn/problems/minimum-ascii-delete-sum-for-two-strings/)  + [solution](../daily/Solution712.ipynb)
# [72. 编辑距离](https://leetcode.cn/problems/edit-distance/) + [solution](/Users/longxingjian/PycharmProjects/algorithm/leetcode/daily/Solution72.ipynb)
# [1035. 不相交的线 1806](https://leetcode.cn/problems/uncrossed-lines/)
# [1458. 两个子序列的最大点积 1824](https://leetcode.cn/problems/max-dot-product-of-two-subsequences/) + [solution](../daily/Solution1458_not_solved.ipynb)
